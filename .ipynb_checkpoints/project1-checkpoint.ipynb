# %%
##importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data = pd.read_csv('activity_context_tracking_data(1).csv')

# %%
Data.head(10)
# Out:
#    _id  orX  orY  orZ        rX        rY        rZ      accX     accY  \
# 0    1  125  -17    2  0.070997 -0.131696 -0.877469 -0.038307  2.68151
# 1    2  126  -17    2  0.071486 -0.131480 -0.878024 -0.038307  2.68151
# 2    3  127  -17    2  0.071401 -0.131551 -0.878799  0.153229  2.68151
# 3    4  127  -17    2  0.071401 -0.131551 -0.878799  0.153229  2.68151
# 4    5  127  -17    2  0.070772 -0.131888 -0.879645  0.153229  2.68151
# 5    6  127  -17    2  0.070772 -0.131888 -0.879645  0.153229  2.68151
# 6    7  127  -17    2  0.069172 -0.132711 -0.881449  0.153229  2.68151
# 7    8  127  -17    2  0.069172 -0.132711 -0.881449  0.153229  2.68151
# 8    9  127  -17    2  0.067182 -0.133712 -0.882605  0.153229  2.68151
# 9   10  127  -17    2  0.067182 -0.133712 -0.882605  0.153229  2.68151
#
#       accZ        gX       gY       gZ    mX    mY    mZ   lux  soundLevel  \
# 0  8.65743 -0.041316  2.67655  8.64271 -31.2 -35.6 -37.6  5000       49.56
# 1  8.65743 -0.054196  2.67834  8.64654 -31.2 -36.0 -37.2  5000       53.38
# 2  8.65743 -0.056867  2.68004  8.65088 -31.2 -36.0 -37.2  5000       53.38
# 3  8.65743 -0.056867  2.68004  8.65088 -31.2 -36.0 -37.2  5000       49.53
# 4  8.65743 -0.049128  2.68130  8.65458 -31.2 -35.6 -36.8  5000       49.53
# 5  8.65743 -0.049128  2.68130  8.65458 -31.2 -35.6 -36.8  5000       49.53
# 6  8.65743 -0.027646  2.68200  8.65709 -31.2 -35.6 -36.8  5000       50.25
# 7  8.65743 -0.027646  2.68200  8.65709 -31.2 -35.6 -36.8  5000       50.25
# 8  8.65743  0.005358  2.68224  8.65839 -31.2 -35.6 -36.4  5000       50.25
# 9  8.65743  0.005358  2.68224  8.65839 -31.2 -35.6 -36.4  5000       50.25
#
#   activity
# 0  Sitting
# 1  Sitting
# 2  Sitting
# 3  Sitting
# 4  Sitting
# 5  Sitting
# 6  Sitting
# 7  Sitting
# 8  Sitting
# 9  Sitting

# %%
Data.isnull()
# Out:
#           _id    orX    orY    orZ     rX     rY     rZ   accX   accY   accZ  \
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 205515  False  False  False  False  False  False  False  False  False  False
# 205516  False  False  False  False  False  False  False  False  False  False
# 205517  False  False  False  False  False  False  False  False  False  False
# 205518  False  False  False  False  False  False  False  False  False  False
# 205519  False  False  False  False  False  False  False  False  False  False
#
#            gX     gY     gZ     mX     mY     mZ    lux  soundLevel  activity
# 0       False  False  False  False  False  False  False       False     False
# 1       False  False  False  False  False  False  False       False     False
# 2       False  False  False  False  False  False  False       False     False
# 3       False  False  False  False  False  False  False       False     False
# 4       False  False  False  False  False  False  False       False     False
# ...       ...    ...    ...    ...    ...    ...    ...         ...       ...
# 205515  False  False  False  False  False  False  False       False     False
# 205516  False  False  False  False  False  False  False       False     False
# 205517  False  False  False  False  False  False  False       False     False
# 205518  False  False  False  False  False  False  False       False     False
# 205519  False  False  False  False  False  False  False       False     False
#
# [205520 rows x 19 columns]

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205520 entries, 0 to 205519
# Data columns (total 19 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   _id         205520 non-null  int64
#  1   orX         205520 non-null  int64
#  2   orY         205520 non-null  int64
#  3   orZ         205520 non-null  int64
#  4   rX          205520 non-null  float64
#  5   rY          205520 non-null  float64
#  6   rZ          205520 non-null  float64
#  7   accX        205520 non-null  float64
#  8   accY        205520 non-null  float64
#  9   accZ        205520 non-null  float64
#  10  gX          205520 non-null  float64
#  11  gY          205520 non-null  float64
#  12  gZ          205520 non-null  float64
#  13  mX          205520 non-null  float64
#  14  mY          205520 non-null  float64
#  15  mZ          205520 non-null  float64
#  16  lux         205520 non-null  int64
#  17  soundLevel  205520 non-null  float64
#  18  activity    205520 non-null  object
# dtypes: float64(13), int64(5), object(1)
# memory usage: 29.8+ MB

# %%
## drope column "id"
Data.drop(['_id'], axis=1)
# Out:
#         orX  orY  orZ        rX        rY        rZ      accX      accY  \
# 0       125  -17    2  0.070997 -0.131696 -0.877469 -0.038307  2.681510
# 1       126  -17    2  0.071486 -0.131480 -0.878024 -0.038307  2.681510
# 2       127  -17    2  0.071401 -0.131551 -0.878799  0.153229  2.681510
# 3       127  -17    2  0.071401 -0.131551 -0.878799  0.153229  2.681510
# 4       127  -17    2  0.070772 -0.131888 -0.879645  0.153229  2.681510
# ...     ...  ...  ...       ...       ...       ...       ...       ...
# 205515  286    6   -2 -0.067944 -0.042220  0.617903 -0.383072 -0.804452
# 205516  286    6   -2 -0.067944 -0.042220  0.617903 -0.383072 -0.804452
# 205517  286    6   -2 -0.067944 -0.042220  0.617903 -0.383072 -0.804452
# 205518  288    4   -2 -0.066261 -0.039767  0.615725 -0.383072 -1.149220
# 205519  288    4   -2 -0.066261 -0.039767  0.615725 -0.383072 -1.149220
#
#             accZ        gX       gY        gZ    mX    mY    mZ   lux  \
# 0        8.65743 -0.041316  2.67655   8.64271 -31.2 -35.6 -37.6  5000
# 1        8.65743 -0.054196  2.67834   8.64654 -31.2 -36.0 -37.2  5000
# 2        8.65743 -0.056867  2.68004   8.65088 -31.2 -36.0 -37.2  5000
# 3        8.65743 -0.056867  2.68004   8.65088 -31.2 -36.0 -37.2  5000
# 4        8.65743 -0.049128  2.68130   8.65458 -31.2 -35.6 -36.8  5000
# ...          ...       ...      ...       ...   ...   ...   ...   ...
# 205515  10.61110 -0.191598 -1.69443  10.55590  31.2  12.8 -35.6  5000
# 205516  10.61110 -0.191598 -1.69443  10.55590  31.2  12.8 -35.6  5000
# 205517  10.61110 -0.191598 -1.69443  10.55590  31.2  12.8 -35.6  5000
# 205518  10.61110 -0.203887 -1.62111  10.47650  31.6  12.4 -35.6  5000
# 205519  10.61110 -0.203887 -1.62111  10.47650  31.6  12.4 -35.6  5000
#
#         soundLevel          activity
# 0            49.56           Sitting
# 1            53.38           Sitting
# 2            53.38           Sitting
# 3            49.53           Sitting
# 4            49.53           Sitting
# ...            ...               ...
# 205515       60.07  DescendingStairs
# 205516       60.07  DescendingStairs
# 205517       60.07  DescendingStairs
# 205518       59.40  DescendingStairs
# 205519       59.40  DescendingStairs
#
# [205520 rows x 18 columns]

# %%
Data.activity.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 205520 entries, 0 to 205519
# Series name: activity
# Non-Null Count   Dtype
# --------------   -----
# 205520 non-null  object
# dtypes: object(1)
# memory usage: 1.6+ MB

# %%
Data['activity'] = pd.factorize(Data['activity'])[0]

# %%
Data.tail(10)
# Out:
#            _id  orX  orY  orZ        rX        rY        rZ      accX  \
# 205510  205511  283    8   -2 -0.067183 -0.043266  0.617256 -0.153229
# 205511  205512  283    8   -2 -0.067183 -0.043266  0.617256 -0.153229
# 205512  205513  283    8   -2 -0.068194 -0.043177  0.618287 -0.383072
# 205513  205514  283    8   -2 -0.068194 -0.043177  0.618287 -0.383072
# 205514  205515  283    8   -2 -0.068194 -0.043177  0.618287 -0.383072
# 205515  205516  286    6   -2 -0.067944 -0.042220  0.617903 -0.383072
# 205516  205517  286    6   -2 -0.067944 -0.042220  0.617903 -0.383072
# 205517  205518  286    6   -2 -0.067944 -0.042220  0.617903 -0.383072
# 205518  205519  288    4   -2 -0.066261 -0.039767  0.615725 -0.383072
# 205519  205520  288    4   -2 -0.066261 -0.039767  0.615725 -0.383072
#
#             accY     accZ        gX       gY       gZ    mX    mY    mZ   lux  \
# 205510 -1.608900  10.2280 -0.165646 -1.72712  10.7521  30.0  12.8 -36.4  5000
# 205511 -1.608900  10.2280 -0.165646 -1.72712  10.7521  30.0  12.8 -36.4  5000
# 205512 -1.225830  10.6111 -0.181502 -1.72720  10.6531  30.4  12.8 -36.0  5000
# 205513 -1.225830  10.6111 -0.181502 -1.72720  10.6531  30.4  12.8 -36.0  5000
# 205514 -1.225830  10.6111 -0.181502 -1.72720  10.6531  30.4  12.8 -36.0  5000
# 205515 -0.804452  10.6111 -0.191598 -1.69443  10.5559  31.2  12.8 -35.6  5000
# 205516 -0.804452  10.6111 -0.191598 -1.69443  10.5559  31.2  12.8 -35.6  5000
# 205517 -0.804452  10.6111 -0.191598 -1.69443  10.5559  31.2  12.8 -35.6  5000
# 205518 -1.149220  10.6111 -0.203887 -1.62111  10.4765  31.6  12.4 -35.6  5000
# 205519 -1.149220  10.6111 -0.203887 -1.62111  10.4765  31.6  12.4 -35.6  5000
#
#         soundLevel  activity
# 205510       59.01        11
# 205511       59.01        11
# 205512       59.01        11
# 205513       59.01        11
# 205514       60.07        11
# 205515       60.07        11
# 205516       60.07        11
# 205517       60.07        11
# 205518       59.40        11
# 205519       59.40        11

# %%
# import seaborn as sns

f, ax = plt.subplots(figsize=(10, 8))
corr = Data.corr()
###plotting heatmap
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(250, 15, as_cmap=True, center = "dark"),
            square=True, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 6
#       4 corr = Data.corr()
#       5 ###plotting heatmap
# ----> 6 sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(250, 15, as_cmap=True, center = "dark"),
#       7             square=True, ax=ax)
#
# NameError: name 'np' is not defined

# %%
#normalize all values in array
data_norm = (Data - Data.min())/ (Data.max() - Data.min())

#view normalized values
data_norm
