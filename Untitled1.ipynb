# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\ABUTHALIB\Desktop\DataScience\Conda_base\project.csv")

# %%
df.isna().sum()
# Out:
# _id           0
# orX           0
# orY           0
# orZ           0
# rX            0
# rY            0
# rZ            0
# accX          0
# accY          0
# accZ          0
# gX            0
# gY            0
# gZ            0
# mX            0
# mY            0
# mZ            0
# lux           0
# soundLevel    0
# activity      0
# dtype: int64

# %%
len(df.loc[df.activity == 'Sitting'])
# Out:
# 75733

# %%
df.activity.unique()
# Out:
# array(['Sitting', 'ClimbingDownStairs', 'Walking', 'Standing',
#        'ClimbingUpStairs', 'Jogging', 'Lying', 'Running', 'Driving',
#        'MountainAscending', 'MountainDescending', 'DescendingStairs',
#        'AscendingStairs'], dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
df.describe()
# Out:
#                  _id            orX            orY            orZ  \
# count  205520.000000  205520.000000  205520.000000  205520.000000
# mean   102760.500000     189.455094       2.726547       0.414120
# std     59328.657999      80.359907      22.446067      12.438395
# min         1.000000       0.000000    -178.000000     -86.000000
# 25%     51380.750000     139.000000      -3.000000      -3.000000
# 50%    102760.500000     186.000000       6.000000      -1.000000
# 75%    154140.250000     268.000000      18.000000       3.000000
# max    205520.000000     359.000000     169.000000      88.000000
#
#                   rX             rY             rZ           accX  \
# count  205520.000000  205520.000000  205520.000000  205520.000000
# mean       -0.017598      -0.011672       0.038061       0.095601
# std         0.148930       0.113509       0.791781       1.948063
# min        -0.712191      -0.556955      -0.999912     -19.536700
# ...

# %%
plt.hist(df.rX,bins=20)
# Out:
# (array([4.7000e+01, 6.8000e+01, 7.3100e+02, 1.8280e+03, 3.0500e+02,
#         3.3900e+02, 5.8200e+02, 4.3306e+04, 5.2045e+04, 7.0933e+04,
#         2.3935e+04, 3.7670e+03, 5.1400e+02, 2.5000e+02, 4.7500e+02,
#         1.6540e+03, 1.3530e+03, 2.8700e+02, 1.2350e+03, 1.8660e+03]),
#  array([-0.712191  , -0.63637345, -0.5605559 , -0.48473835, -0.4089208 ,
#         -0.33310325, -0.2572857 , -0.18146815, -0.1056506 , -0.02983305,
#          0.0459845 ,  0.12180205,  0.1976196 ,  0.27343715,  0.3492547 ,
#          0.42507225,  0.5008898 ,  0.57670735,  0.6525249 ,  0.72834245,
#          0.80416   ]),
#  <BarContainer object of 20 artists>)

# %%
import seaborn as sns

# %%
dfn = df.drop(['activity'],axis=1)
dfn
# Out:
#            _id  orX  orY  orZ        rX        rY        rZ      accX  \
# 0            1  125  -17    2  0.070997 -0.131696 -0.877469 -0.038307
# 1            2  126  -17    2  0.071486 -0.131480 -0.878024 -0.038307
# 2            3  127  -17    2  0.071401 -0.131551 -0.878799  0.153229
# 3            4  127  -17    2  0.071401 -0.131551 -0.878799  0.153229
# 4            5  127  -17    2  0.070772 -0.131888 -0.879645  0.153229
# ...        ...  ...  ...  ...       ...       ...       ...       ...
# 205515  205516  286    6   -2 -0.067944 -0.042220  0.617903 -0.383072
# 205516  205517  286    6   -2 -0.067944 -0.042220  0.617903 -0.383072
# 205517  205518  286    6   -2 -0.067944 -0.042220  0.617903 -0.383072
# 205518  205519  288    4   -2 -0.066261 -0.039767  0.615725 -0.383072
# 205519  205520  288    4   -2 -0.066261 -0.039767  0.615725 -0.383072
#
#             accY      accZ        gX       gY        gZ    mX    mY    mZ  \
# ...

# %%
dfn.corr()

# %%
sns.heatmap(dfn.co,annot=True)
